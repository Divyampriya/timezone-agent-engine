# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyampriya/timezone-agent-engine/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
from google.colab import userdata
genai.configure(
    api_key=userdata.get('GOOGLE_API_KEY')
)

# List available models to find a suitable one
# for m in genai.list_models():
#   if 'generateContent' in m.supported_generation_methods:
#     print(m.name)

# Changing to 'gemini-pro' as it's a generally available and supported model
model = genai.GenerativeModel('gemini-3.1-flash-lite')
def simple_agent(prompt):
  # Define a local model for this function to use the specified preview version
  local_model = genai.GenerativeModel('gemini-3.1-flash-lite-preview')
  # Generate content and assign the result to the 'response' variable
  response = local_model.generate_content(prompt)
  return response.text
question ="explain difference between AI agent and Agentic AI"
answer = simple_agent(question)
print(answer)
# Out:
# While the terms "AI Agent" and "Agentic AI" are often used interchangeably in casual conversation, there is a nuanced difference between them in the context of computer science and industry strategy.
#
# Think of it as the difference between a **tool** and a **philosophy of design.**
#
# ---
#
# ### 1. What is an AI Agent?
# An **AI Agent** is a specific, self-contained system. It is a piece of software that uses an LLM (or other AI model) as its "brain" to perceive its environment, reason, and take actions to achieve a specific goal.
#
# **Core Characteristics:**
# *   **Autonomy:** It can execute steps without the user prompting it for every single click.
# *   **Tool Use:** It can access external APIs, search the web, write files, or trigger software workflows.
# *   **Goal-Oriented:** It is designed for a specific task (e.g., "Book a flight," "Debug this code," or "Manage my email inbox").
#
# ...
